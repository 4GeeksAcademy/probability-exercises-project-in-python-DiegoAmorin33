# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random

sumas = []
for i in range(1000):
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)
    suma = dado1 + dado2
    sumas.append(suma)

contador = 0
for suma in sumas:
    if suma > 7 or suma % 2 == 0:
        contador += 1

probabilidad = contador / 1000

print("Total de lanzamientos:", len(sumas))
print("Veces que cumple la condición:", contador)
print("Probabilidad estimada:", probabilidad)
# Out:
# Total de lanzamientos: 1000
# Veces que cumple la condición: 687
# Probabilidad estimada: 0.687

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import numpy as np

caja_bolas = {}
for i in range(60):
    if i < 10:
        caja_bolas[i] = "Blanca"
    elif i < 30:
        caja_bolas[i] = "Roja"
    else:
        caja_bolas[i] = "Verde"

def extraer_bolas(n_experimentos=1000):
    conteo_blancas_rojas = 0
    conteo_mismo_color = 0

    for _ in range(n_experimentos):
        colores = []

        for _ in range(5):
            indice = np.random.randint(0, 59)  
            colores.append(caja_bolas[indice])

        colores = np.array(colores)

        blancas = sum(colores == "Blanca")
        rojas = sum(colores == "Roja")
        verdes = sum(colores == "Verde")

        if blancas == 3 and rojas == 2:
            conteo_blancas_rojas += 1

        if blancas == 5 or rojas == 5 or verdes == 5:
            conteo_mismo_color += 1

    p_blancas_rojas = conteo_blancas_rojas / n_experimentos
    p_mismo_color = conteo_mismo_color / n_experimentos

    return p_blancas_rojas, p_mismo_color


probabilidades = extraer_bolas(1000)

print(f"Probabilidad de 3 blancas y 2 rojas: {np.round(probabilidades[0] * 100, 2)}%")
print(f"Probabilidad de todas del mismo color: {np.round(probabilidades[1] * 100, 2)}%")
# Out:
# Probabilidad de 3 blancas y 2 rojas: 0.8%
# Probabilidad de todas del mismo color: 3.3%
